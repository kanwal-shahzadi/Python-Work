# %% [markdown]
# # Defining new functions

# %% [markdown]
# We can define new functions using the ```def``` command.

# %%
# Builtin or Pre-Build or Pre-Defined
# help()
# max()
# min()
# type()
# pow()
# sqrt()
# print()

# %%
def NAME(a, b):
    Take Start

# %%
def square(x):
    return x * x   # notice the indentation

# %%
square(3)
# Out:
# 9

# %% [markdown]
# And we <b>call</b> this function as before.

# %%
v = square(5)

# %%
v
# Out:
# 25

# %% [markdown]
# Let's discussion these two in detail.

# %% [markdown]
# Aside: in C, functions are defined as following:
#
# <img align='left' src='imgs/c-func-def.png' width='450px' />

# %% [markdown]
# Obviously, we can a call function within other functions.

# %%
def sum_squares(x, y):
    return square(x) + square(y)

# %%
z = sum_squares(3, 4)

# %%
z
# Out:
# 25

# %% [markdown]
# We want to see what happens here exactly. Let's move to the interactive tutor.

# %%
sum_squares('a', 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sum_squares('a', 3)
#
# Cell In[12], line 2, in sum_squares(x, y)
#       1 def sum_squares(x, y):
# ----> 2     return square(x) + square(y)
#
# Cell In[7], line 2, in square(x)
#       1 def square(x):
# ----> 2     return x * x
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# There's another important point here that we highlight through our slide.

# %% [markdown]
# ### Default values

# %% [markdown]
# We can give meaningful default values to arguments. Let's  see an example from our favorite square root function.

# %%
def sqrt(num, guess): 
    print("Finding square root of", num, "starting with guess:", guess)

# %%
sqrt(36, 1)    # but we don't need to specify the 1
# Out:
# Finding square root of 36 starting with guess: 1

# %%
sqrt(36)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sqrt(36)
#
# TypeError: sqrt() missing 1 required positional argument: 'guess'

# %%
def sqrt(num, guess=5.0): 
    print("Finding square root of", num, "starting with guess:", guess)

# %%
sqrt(36)
# Out:
# Finding square root of 36 starting with guess: 5.0

# %%
sqrt(36, 6.1)
# Out:
# Finding square root of 36 starting with guess: 6.1

# %%
sqrt(36)
# Out:
# Finding square root of 36 starting with guess: 5.0

# %% [markdown]
# ASSIGNMENT NO. 2          (FUNCTION RELATED PROBLEMS)

# %% [markdown]
# Question : 1         Write a function that takes two numbers as parameters and returns their sum.

# %%
def add_numbers (a , b):
    return a+b

# %%
x=add_numbers

# %%
a=5
b=15

# %%
x=add_numbers(5, 15)

# %%
x
# Out:
# 20

# %%
print("Sum of two numbers is:" , x)
# Out:
# Sum of two numbers is: 20

# %% [markdown]
# Question : 2    Write a function that takes a radius as a parameter and returns the area of a circle using math.pi.

# %%
3**2
# Out:
# 9

# %%
import math
def circle_area (radius):
    return math.pi * radius**2

# %%
print("Area of a Circle is:", circle_area(5))
# Out:
# Area of a Circle is: 78.53981633974483

# %% [markdown]
# Question: 3    Write a function with a default parameter that calculates the power of a number. If the power is not provided, use 2 as the default.

# %%
def power(num=2):
    return num*num

# %%
def power(num,p=2):
    return num**p

# %%
y=power(3)

# %%
y
# Out:
# 9

# %%
print('Power of number is:',y)
# Out:
# Power of number is: 9

# %% [markdown]
# Question: 4   Write a function that takes three numbers and returns the maximum value using max().

# %%
def max_function(a,b, c):
    return max(a,b,c)

# %%
max_function(14,1,19)
# Out:
# 19

# %%
print("Maximum value is:" ,max_function(25,7,19))
# Out:
# Maximum value is: 25

# %% [markdown]
# Question: 5         Write a function that prints a message. Call this function from another function.

# %%
def print_message(hello):
    print (hello)

# %%
print_message("welcome to python")
# Out:
# welcome to python

# %% [markdown]
# Question: 6         Write a function that calculates the average of two numbers and call it from another function that prints the result.

# %%
def average (x,y):
    return (x+y )/2

# %%
def print_average():
    aveg=average(5,3)
    print ("the average is:",aveg)

# %%
print_average()
# Out:
# the average is: 4.0

# %% [markdown]
# Question: 7        Write a function that takes a number and returns both its square root and square using math.sqrt() and math.pow().

# %%
import math
def sqrt_and_square(number):
    return math.sqrt(number),math.pow (number,2)

# %%
number=5
sqrt_and_square(number)
# Out:
# (2.23606797749979, 25.0)

# %%
a,b=sqrt_and_square(number)
print('square root is:',a)
print("square is:",b)
# Out:
# square root is: 2.23606797749979
# square is: 25.0

# %% [markdown]
# Question: 8      Write a function with one required parameter and one optional parameter. Call the function using both one argument and two arguments.

# %%
def function(x, y=None):
    print (x," ,", y)

# %%
function (5)
# Out:
# 5  , None

# %%
function (3,4)
# Out:
# 3  , 4

# %% [markdown]
# Question: 9       Write a function that takes length and width as parameters and returns the area of a rectangle. Call this function multiple times with different values.

# %%
def rectangle_area(length,width):
    return length*width

# %%
rectangle_area(6,10)
# Out:
# 60

# %%
rectangle_area(5,4)
# Out:
# 20

# %% [markdown]
# Question: 10      Write a function that calls another function to calculate the circumference of a circle using math.pi.

# %%
import math
def circle_circumference(radius):
    return 2*math.pi*radius

# %%
def print_cicumference():
    ans=circle_circumference(5)
    print('the cicumfernce is:',ans)

# %%
print_cicumference()
# Out:
# the cicumfernce is: 31.41592653589793
