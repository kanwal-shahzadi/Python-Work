# %% [markdown]
# ### Lexical Scope

# %% [markdown]
# Where can you see the variables?

# %%
def f(x):             # name x used as formal parameter              
    y = 1             # local variable 
    x = x + y        
    print('. x =', x)    
    print('. p =', p)    # global variable 
    return x

# %%
p = 10
x = 3
y = 2    
z = f(x) #value of x used as actual parameter
print('The returned value of f(x) is:', z)
print('x =', x)
print('y =', y)
# Out:
# . x = 4
# . p = 10
# The returned value of f(x) is: 4
# x = 3
# y = 2

# %% [markdown]
# Let's see this in the tutor.

# %%
#y = 25
def f(): 
    y = 25 
    '''This function is just for testing purposes.''' 
    print('y =', y)
    y = 1   # variables are global unless assigned to inside the function     

f()
# Out:
# y = 25

# %%
help(f)
# Out:
# Help on function f in module __main__:
#
# f()
#     This function is just for testing purposes.

# %%
 #y = 25
def f():   
     global y 
     y = 25
     print('y =', y)
     y = 1   # variables are global unless assigned to inside the function  
     print('y =', y)   

f()
# Out:
# y = 25
# y = 1

# %% [markdown]
# ## Reading Assignment
#
# You need to read sections "1.3.5 Choosing Names" and "1.3.6 Functions as Abstractions" on the Composing Programs page at: http://www.composingprograms.com/pages/13-defining-new-functions.html

# %% [markdown]
# # Designing Functions
#
# It's important to design your functions thoughtfully. Some important points to note:
#
# * Functions are abstractions. So, their operation should depend as little on the environment as possible
# * Names should be intuitive and meaningful
# * Parameters should be named intuitively as well
# * Functions should be documented!

# %%
def pressure(v, t, n):
        """Compute the pressure in pascals of an ideal gas. (This is called a docstring.)
        Applies the ideal gas law.
        v -- volume of gas, in cubic meters
        t -- absolute temperature in degrees kelvin
        n -- particles of gas
        """
        k = 1.38e-23  # Boltzmann's constant
        return n * k * t / v

# %%
help(pressure)
# Out:
# Help on function pressure in module __main__:
#
# pressure(v, t, n)
#     Compute the pressure in pascals of an ideal gas. (This is called a docstring.)
#     Applies the ideal gas law.
#     v -- volume of gas, in cubic meters
#     t -- absolute temperature in degrees kelvin
#     n -- particles of gas

# %%
name = input("Enter your name: ")

# %%
name = input("Enter you name: ")
age = int(input("Enter your age: "))

# %%
print("Hello ",name,", next year you will be ",age+1," years old")
# Out:
# Hello  Kanwal Shehzadi , next year you will be  101  years old

# %%
f_name, last_name
# Out:
# ('Kanwal', 'Shehzadi')

# %%
user_input_values = input("Enter list of numbers:")

# %%
type(user_input_values)
# Out:
# str

# %%
user_input_values
# Out:
# '1,2,3,4'

# %%
user_input_values.split(',')
# Out:
# ['1', '2', '3', '4']

# %% [markdown]
# # First Heading
# ## Second Heading
# ### 3rd Heading
# #### 4th Heading
#
# - Hello
# - World
# - How
# - Are
# - You
#
# ---

# %% [markdown]
# 1- Declare a global variable and write a function that prints its value.

# %%
x=5    #global value
def f():
    print('value of x:',x)
    return x
f()
# Out:
# value of x: 5
# 5

# %%
print(f())
# Out:
# value of x: 5
# 5

# %% [markdown]
# 2- Write a function that takes one parameter and prints the parameter value.

# %%
def f(x):
    print ("the parameter value is:",x)

# %% [markdown]
# 3- Declare a variable outside a function and another variable with the same name inside the function. Print both values to see which one is used where.

# %%
x=7       #global variable
def f():
    x=2        #local variable
    print('value of inside the function:', x)
    return x

# %%
f()
print('value of outside a function:', x)   #global variable
# Out:
# value of inside the function: 2
# value of outside a function: 7

# %% [markdown]
# 4- Write a function that returns a value and print the returned value outside the function.

# %%
def f(x,y):
    return x+y

# %%
x=2
y=9
sum=f(x,y)
print("sum is:",sum)
# Out:
# sum is: 11

# %% [markdown]
# 5- Declare a global variable and change its value inside a function using the global keyword.

# %%
z=7
def f():
    global z
    z=2
    return z

# %%
f()
print("global value inside a function:",z)
# Out:
# global value inside a function: 2

# %% [markdown]
# 6- Write a function that defines a local variable and prints it. Try printing the same variable outside the function.

# %%
def f():
    a=3
    print('value of local variable is:',a)

# %%
f()
print(" outside the function",a)
# Out:
# value of local variable is: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 f()
# ----> 2 print(" outside the function",a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# 7- Write two functions where one function calls the other and prints the returned value.

# %%
def multiplication(x,y):
    return x*y
def print_multiplication(a,b):
    z=multiplication(a,b)
    print("the value of multiplication is:",z)

# %%
print_multiplication(3,5)
# Out:
# the value of multiplication is: 15
