# %% [markdown]
# # Compound statements

# %% [markdown]
# Compound statements take the form:
#
#     <header>:
#         <statement>
#         <statement>
#         ...
#     <separating header>:
#         <statement>
#         <statement>
#         ...
#     ...

# %% [markdown]
# Functions are a form of compound statements. For instance:

# %%
def percent_difference(x, y):
    difference = abs(x-y)
    return 100 * difference / x

result = percent_difference(40, 50)

# %%
result
# Out:
# 25.0

# %% [markdown]
# <b>Important note:</b> Python forces you to do indentation! Many other languages don't but you still have to get in the habbit of proper indentation.
#
# Make sure you understand the difference between indenting with tabs and that with spaces. Also ensure you understand the capabilities of your text editor.

# %% [markdown]
# ## Conditionals

# %% [markdown]
# Also called <b>branching statements</b>. These allow you to make decisions.

# %%
def absolute_value(x):
    """Compute abs(x)."""
    
    if x > 0:
        return x
    elif x == 0: # Else-if [agr wo(ooper wala) nahi tu yeh]
        return 0 
    else:   # Ooper waloo ma say koi b nahi ha tu yeh (otherwise)
        return -1*x

# %%
absolute_value(-5)
# Out:
# 5

# %%
absolute_value(6)
# Out:
# 6

# %%
absolute_value(0)
# Out:
# 0

# %%
absolute_value(-0.1)
# Out:
# 0.1

# %% [markdown]
# Let's view this in the tutor.

# %% [markdown]
# Aside: In C, `if` looks like this:
#
# <img align='left' src='imgs/c-if.png' width='250px' />

# %%
not 5 < 0
# Out:
# True

# %%
# Another way to write this: 
def absolute_value(x):
    """Compute abs(x)."""
    if not x < 0:
        return x
    else:
        return -1*x

# %%
absolute_value(-3)
# Out:
# 3

# %%
# we can also nest ifs 
a = 9
b = 8

if a > 5:
    if b > 6: 
        print("a is more than 5 and b is more than 6")
    else: 
        print("a is more than 5 BUT b is not more than 6")
        
else: 
    print("a is not more than 5")

print("done")
# Out:
# a is more than 5 and b is more than 6
# done

# %%
import datetime
def is_weekday(day, month, year): 
    return datetime.datetime(year=year, month=month, day=day).weekday() < 5

# %%
if is_weekday(27, 12, 2025):
    print("It's a weekday.")
else: 
    print("Weekend!!")
# Out:
# Weekend!!

# %% [markdown]
# Assignment NO : 4
#
#
# 1- Write a program that checks whether a number is positive or negative using an if-else statement.

# %%
number=6
if number >=0:
    print('+ve num')
else: 
    print ("-ve number")
# Out:
# +ve num

# %% [markdown]
# 2- Write a program that checks whether a number is even or odd using an if-else statement.

# %%
number= 9
if number % 2==0:
    print("even number")
else:
      print("odd number")
# Out:
# odd number

# %% [markdown]
# 3- Write a program that takes a student’s marks and prints Pass if marks are 50 or above, otherwise prints Fail.

# %%
marks=49.9
if marks >=50:
    print("pass")
else:
    print("fail")
# Out:
# fail

# %% [markdown]
# 4- Write a program that takes a number and checks whether it is positive, negative, or zero using if-elif-else.

# %%
number= 4
if number > 0:
    print("+ve")
elif  number < 0:
    print("-ve")
else:
    print("zero")
# Out:
# +ve

# %% [markdown]
# 5- Write a program that takes three numbers and prints the largest number using nested if statements.

# %%
x=4
y=9
z=2
if x>y:
    if x>z:
       print("x is largest") 
    else:
        print("z is largest")  
else:
    if y>z:
       print("y is largest") 
    else:
        print("z is largest")
# Out:
# y is largest

# %% [markdown]
# 6- Write a program that takes age as input and determines whether the person is a child(<8), teenager(<16), or adult(>=16) using if-elif-else.

# %%
age = -4
if age <0:
    print("age should not be -ve")
elif age < 8:
    print("Child")
elif age < 16:
    print("Teenager")
elif  age>=16:
     print("Adult")
else:
    print(" invalid age")
# Out:
# age should not be -ve

# %% [markdown]
# 7- Write a program that takes a year and checks whether it is a leap year using conditional statements.

# %%
leap year:(divisible by 4
not divisible by 100
unless it is divisible by 400)

# %%
year=2020
if year %4==0:
    if year %100!=0:       #  !=  (not equal to)
       print ("leap year") 
elif  year %400==0:
     print ("leap year") 
else:
    print ("not a leap year")
# Out:
# leap year
